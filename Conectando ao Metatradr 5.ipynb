# %% [markdown]
# # Conectando ao Metatrader 5

# %% [markdown]
# ### Instalando a biblioteca MT5
# ##### Vamos utilizar o comando pip install para instalar o MT5 no VS Code
# !pip install MetaTrader5

# %% [markdown]
# #### Importando bibliotecas

# %%
import pandas as pd
import MetaTrader5 as mt5 
import functions as fc 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Inicializando a Conexão

# %%
if not mt5.initialize():
    print('Inicialização falhou!')
    mt5.shutdown()
else:
    print('Inicialização concluida!')
# Out:
# Inicialização concluida!

# %%
symbols = ['EURUSD', 'GBPUSD', 'USDJPY', 'USDCHF']
data= pd.DataFrame()

# %%
for i in symbols: 
    df = mt5.copy_rates_from_pos(i, mt5.TIMEFRAME_H1, 0 ,9999)
    df = pd.DataFrame(df)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    df = df[['time','close']].set_index('time')
    df = df.rename(columns={'close':f'{i}'})
    data = pd.concat([df, data], axis = 1)

# %%
data
# Out:
#                       USDCHF   USDJPY   GBPUSD   EURUSD
# time
# 2019-07-10 05:00:00  0.99326      NaN      NaN  1.12100
# 2019-07-10 06:00:00  0.99309  108.893      NaN  1.12071
# 2019-07-10 07:00:00  0.99297  108.860  1.24542  1.12073
# 2019-07-10 08:00:00  0.99309  108.860  1.24556  1.12097
# 2019-07-10 09:00:00  0.99237  108.927  1.24524  1.12125
# ...                      ...      ...      ...      ...
# 2021-02-18 16:00:00  0.89720  105.835  1.39570  1.20705
# 2021-02-18 17:00:00  0.89748  105.783  1.39450  1.20721
# 2021-02-18 18:00:00  0.89681  105.698  1.39561  1.20773
# 2021-02-18 19:00:00  0.89632  105.651  1.39636  1.20819
# 2021-02-18 20:00:00  0.89623  105.644  1.39662  1.20836
#
# [10001 rows x 4 columns]

# %%
fc.graf_plotly(data, 'data')

# %%
mt5.shutdown()
# Out:
# True
